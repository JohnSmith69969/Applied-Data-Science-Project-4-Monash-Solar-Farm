# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# %%
df = pd.read_csv('building_solar_values.csv')
df = df.iloc[:, 1:]
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#                       Date  Building0  Building1  Building3  Building4  \
# 0      2016-07-04 07:30:00      283.8        NaN      581.0        NaN
# 1      2016-07-04 07:45:00      283.8        NaN      581.0        NaN
# 2      2016-07-04 08:00:00      283.8        NaN      581.0        NaN
# 3      2016-07-04 08:15:00      606.0        NaN      624.0        NaN
# 4      2016-07-04 08:30:00      606.0        NaN      624.0        NaN
# ...                    ...        ...        ...        ...        ...
# 151781 2020-11-01 08:45:00      105.0        8.4      322.0        1.0
# 151782 2020-11-01 09:00:00      105.0       11.3      322.0        NaN
# 151783 2020-11-01 09:15:00       77.6        2.3      327.0        NaN
# 151784 2020-11-01 09:30:00       77.6        5.1      327.0        1.0
# 151785 2020-11-01 09:45:00       77.6        7.8      327.0        1.0
#
#         Building5  Building6  Solar0  Solar1  Solar2  Solar3  Solar4  Solar5
# 0             NaN        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1             NaN        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2             NaN        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3             NaN        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4             NaN        NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...           ...        ...     ...     ...     ...     ...     ...     ...
# 151781        NaN       26.4   18.53    4.96    4.73    4.31    2.84   13.47
# 151782        NaN       26.6   22.23    5.88    5.64    5.08    3.40   15.93
# 151783        NaN       26.6   23.39    6.31    5.99    5.45    3.62   17.11
# 151784        NaN       27.4   24.56    6.73    6.35    5.83    3.85   18.29
# 151785        NaN       27.4   28.23    7.34    7.30    6.76    4.49   20.64
#
# [151786 rows x 13 columns]

# %%
df = df.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6'])
df
# Out:
#                       Date  Solar0  Solar1  Solar2  Solar3  Solar4  Solar5
# 0      2016-07-04 07:30:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1      2016-07-04 07:45:00     NaN     NaN     NaN     NaN     NaN     NaN
# 2      2016-07-04 08:00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 3      2016-07-04 08:15:00     NaN     NaN     NaN     NaN     NaN     NaN
# 4      2016-07-04 08:30:00     NaN     NaN     NaN     NaN     NaN     NaN
# ...                    ...     ...     ...     ...     ...     ...     ...
# 151781 2020-11-01 08:45:00   18.53    4.96    4.73    4.31    2.84   13.47
# 151782 2020-11-01 09:00:00   22.23    5.88    5.64    5.08    3.40   15.93
# 151783 2020-11-01 09:15:00   23.39    6.31    5.99    5.45    3.62   17.11
# 151784 2020-11-01 09:30:00   24.56    6.73    6.35    5.83    3.85   18.29
# 151785 2020-11-01 09:45:00   28.23    7.34    7.30    6.76    4.49   20.64
#
# [151786 rows x 7 columns]

# %% [markdown]
# # Solar 0

# %%
Solar0 = df.drop(columns=['Solar1','Solar2','Solar3','Solar4','Solar5'])
Solar0
# Out:
#                       Date  Solar0
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00   18.53
# 151782 2020-11-01 09:00:00   22.23
# 151783 2020-11-01 09:15:00   23.39
# 151784 2020-11-01 09:30:00   24.56
# 151785 2020-11-01 09:45:00   28.23
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar0['Date'], Solar0['Solar0'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 0 power output')
plt.grid(True)
plt.show()

# %%
Solar0.set_index('Date', inplace=True)
s = Solar0.index > '2020-05-31 23:45:00'
t = Solar0.index < '2020-11-01 00:00:00'
Solar0 = Solar0[s&t]
Solar0
# Out:
#                      Solar0
# Date
# 2020-06-01 00:00:00    0.01
# 2020-06-01 00:15:00    0.01
# 2020-06-01 00:30:00    0.01
# 2020-06-01 00:45:00    0.01
# 2020-06-01 01:00:00    0.01
# ...                     ...
# 2020-10-31 22:45:00    0.01
# 2020-10-31 23:00:00    0.01
# 2020-10-31 23:15:00    0.01
# 2020-10-31 23:30:00    0.01
# 2020-10-31 23:45:00    0.01
#
# [14688 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2020-05-31 23:45:00'
weather = weather[s]
weather
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2020-06-01 00:00:00              11.200                        8.000
# 2020-06-01 00:15:00              11.200                        7.975
# 2020-06-01 00:30:00              11.200                        7.950
# 2020-06-01 00:45:00              11.200                        7.925
# 2020-06-01 01:00:00              11.200                        7.900
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-06-01 00:00:00              5.90                    100652.600
# 2020-06-01 00:15:00              6.00                    100626.100
# 2020-06-01 00:30:00              6.10                    100599.600
# 2020-06-01 00:45:00              6.20                    100573.100
# 2020-06-01 01:00:00              6.30                    100546.600
# ...                               ...                           ...
# 2021-06-01 09:00:00              5.60                    102077.100
# 2021-06-01 09:15:00              5.55                    102085.225
# 2021-06-01 09:30:00              5.50                    102093.350
# 2021-06-01 09:45:00              5.45                    102101.475
# 2021-06-01 10:00:00              5.40                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2020-06-01 00:00:00                      0.800
# 2020-06-01 00:15:00                      0.800
# 2020-06-01 00:30:00                      0.800
# 2020-06-01 00:45:00                      0.800
# 2020-06-01 01:00:00                      0.800
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-06-01 00:00:00                            0.000
# 2020-06-01 00:15:00                            0.000
# 2020-06-01 00:30:00                            0.000
# 2020-06-01 00:45:00                            0.000
# 2020-06-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-06-01 00:00:00                            309.400
# 2020-06-01 00:15:00                            309.625
# 2020-06-01 00:30:00                            309.850
# 2020-06-01 00:45:00                            310.075
# 2020-06-01 01:00:00                            310.300
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2020-06-01 00:00:00                      0.2
# 2020-06-01 00:15:00                      0.3
# 2020-06-01 00:30:00                      0.4
# 2020-06-01 00:45:00                      0.5
# 2020-06-01 01:00:00                      0.6
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [35081 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar5','Solar1','Solar2','Solar3','Solar4'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data = nov_data[t]
nov_data
# Out:
#                      Solar0
# Date
# 2020-11-01 10:00:00   31.90
# 2020-11-01 10:15:00   32.02
# 2020-11-01 10:30:00   32.14
# 2020-11-01 10:45:00   36.68
# 2020-11-01 11:00:00   41.22
# ...                     ...
# 2020-11-30 22:45:00    0.01
# 2020-11-30 23:00:00    0.01
# 2020-11-30 23:15:00    0.01
# 2020-11-30 23:30:00    0.01
# 2020-11-30 23:45:00    0.01
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y-train

# %%
#power output data from 2020/06/01 - 2020-10-31

Solar0
# Out:
#                      Solar0
# Date
# 2020-06-01 00:00:00    0.01
# 2020-06-01 00:15:00    0.01
# 2020-06-01 00:30:00    0.01
# 2020-06-01 00:45:00    0.01
# 2020-06-01 01:00:00    0.01
# ...                     ...
# 2020-10-31 22:45:00    0.01
# 2020-10-31 23:00:00    0.01
# 2020-10-31 23:15:00    0.01
# 2020-10-31 23:30:00    0.01
# 2020-10-31 23:45:00    0.01
#
# [14688 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
#power output data from 2020/11/01 - 2020-11-30

nov_data
# Out:
#                      Solar0
# Date
# 2020-11-01 10:00:00   31.90
# 2020-11-01 10:15:00   32.02
# 2020-11-01 10:30:00   32.14
# 2020-11-01 10:45:00   36.68
# 2020-11-01 11:00:00   41.22
# ...                     ...
# 2020-11-30 22:45:00    0.01
# 2020-11-30 23:00:00    0.01
# 2020-11-30 23:15:00    0.01
# 2020-11-30 23:30:00    0.01
# 2020-11-30 23:45:00    0.01
#
# [2840 rows x 1 columns]

# %% [markdown]
# # X - train

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather.index < '2020-11-01 00:00:00'
weather_train = weather[t]
weather_train = weather_train[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-06-01 00:00:00                            309.400
# 2020-06-01 00:15:00                            309.625
# 2020-06-01 00:30:00                            309.850
# 2020-06-01 00:45:00                            310.075
# 2020-06-01 01:00:00                            310.300
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-06-01 00:00:00                              0.0
# 2020-06-01 00:15:00                              0.0
# 2020-06-01 00:30:00                              0.0
# 2020-06-01 00:45:00                              0.0
# 2020-06-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-06-01 00:00:00                    100652.600
# 2020-06-01 00:15:00                    100626.100
# 2020-06-01 00:30:00                    100599.600
# 2020-06-01 00:45:00                    100573.100
# 2020-06-01 01:00:00                    100546.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-06-01 00:00:00                        8.000               11.20
# 2020-06-01 00:15:00                        7.975               11.20
# 2020-06-01 00:30:00                        7.950               11.20
# 2020-06-01 00:45:00                        7.925               11.20
# 2020-06-01 01:00:00                        7.900               11.20
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [14688 rows x 5 columns]

# %% [markdown]
# # X - train

# %%
s = weather.index >= '2020-11-01 10:00:00'
t = weather.index < '2020-12-01 00:00:00'
weather_test = weather[s&t]
weather_test = weather_test[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train = weather_train
X_train = (X_train-X_train.mean())/X_train.std()

# %%
X_test = weather_test
X_test = (X_test-X_test.mean())/X_test.std()

# %%
Y_train = Solar0['Solar0']
Y_test = nov_data['Solar0']

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=200,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train, Y_train)
predictions = regressor.predict(X_test)

MSE = mean_squared_error(Y_test, predictions)
print("MSE:", MSE)

total = np.sum((Y_test - np.mean(Y_test))**2)
residual = np.sum((Y_test - predictions)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 112.49599334905308
# R^2: 0.5779845466514895

# %%
results = pd.DataFrame({'Actual': Y_test, 'Predicted': predictions})
results
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00   31.90  13.408034
# 2020-11-01 10:15:00   32.02  14.041960
# 2020-11-01 10:30:00   32.14  18.054901
# 2020-11-01 10:45:00   36.68  18.054901
# 2020-11-01 11:00:00   41.22  19.874449
# ...                     ...        ...
# 2020-11-30 22:45:00    0.01   0.282476
# 2020-11-30 23:00:00    0.01   0.301371
# 2020-11-30 23:15:00    0.01   0.301371
# 2020-11-30 23:30:00    0.01   0.184032
# 2020-11-30 23:45:00    0.01   0.184032
#
# [2840 rows x 2 columns]

# %%
# print('X_train:',X_train.shape)
# print('X_test:',X_test.shape)
# print('Y_train:',Y_train.shape)
# print('Y_test:',Y_test.shape)

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Solar 1

# %%
Solar1 = df.drop(columns=['Solar0','Solar2','Solar3','Solar4','Solar5'])
Solar1
# Out:
#                       Date  Solar1
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00    4.96
# 151782 2020-11-01 09:00:00    5.88
# 151783 2020-11-01 09:15:00    6.31
# 151784 2020-11-01 09:30:00    6.73
# 151785 2020-11-01 09:45:00    7.34
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar1['Date'], Solar1['Solar1'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 1 power output')
plt.grid(True)
plt.show()

# %%
Solar1.set_index('Date', inplace=True)
s = Solar1.index > '2019-09-30 23:49:00'
t = Solar1.index < '2020-11-01 00:00:00'
Solar1 = Solar1[s&t]
Solar1
# Out:
#                      Solar1
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2019-09-30 23:49:00'
weather1 = weather[s]
weather1
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2019-10-01 00:00:00               6.600                        4.400
# 2019-10-01 00:15:00               6.400                        4.325
# 2019-10-01 00:30:00               6.200                        4.250
# 2019-10-01 00:45:00               6.000                        4.175
# 2019-10-01 01:00:00               5.800                        4.100
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00             2.100                    103031.800
# 2019-10-01 00:15:00             2.075                    103022.500
# 2019-10-01 00:30:00             2.050                    103013.200
# 2019-10-01 00:45:00             2.025                    103003.900
# 2019-10-01 01:00:00             2.000                    102994.600
# ...                               ...                           ...
# 2021-06-01 09:00:00             5.600                    102077.100
# 2021-06-01 09:15:00             5.550                    102085.225
# 2021-06-01 09:30:00             5.500                    102093.350
# 2021-06-01 09:45:00             5.450                    102101.475
# 2021-06-01 10:00:00             5.400                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2019-10-01 00:00:00                      0.900
# 2019-10-01 00:15:00                      0.900
# 2019-10-01 00:30:00                      0.900
# 2019-10-01 00:45:00                      0.900
# 2019-10-01 01:00:00                      0.900
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            0.000
# 2019-10-01 00:15:00                            0.000
# 2019-10-01 00:30:00                            0.000
# 2019-10-01 00:45:00                            0.000
# 2019-10-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2019-10-01 00:00:00                      0.1
# 2019-10-01 00:15:00                      0.1
# 2019-10-01 00:30:00                      0.1
# 2019-10-01 00:45:00                      0.1
# 2019-10-01 01:00:00                      0.1
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [58505 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar5','Solar0','Solar2','Solar3','Solar4'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data1 = nov_data[t]
nov_data1
# Out:
#                      Solar1
# Date
# 2020-11-01 10:00:00    7.95
# 2020-11-01 10:15:00    8.51
# 2020-11-01 10:30:00    9.07
# 2020-11-01 10:45:00    9.38
# 2020-11-01 11:00:00    9.68
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y - train (solar 1)

# %%
Solar1
# Out:
#                      Solar1
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
nov_data1
# Out:
#                      Solar1
# Date
# 2020-11-01 10:00:00    7.95
# 2020-11-01 10:15:00    8.51
# 2020-11-01 10:30:00    9.07
# 2020-11-01 10:45:00    9.38
# 2020-11-01 11:00:00    9.68
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # X - train

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather1.index < '2020-11-01 00:00:00'
weather_train1 = weather1[t]
weather_train1 = weather_train1[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train1
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                              0.0
# 2019-10-01 00:15:00                              0.0
# 2019-10-01 00:30:00                              0.0
# 2019-10-01 00:45:00                              0.0
# 2019-10-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00                    103031.800
# 2019-10-01 00:15:00                    103022.500
# 2019-10-01 00:30:00                    103013.200
# 2019-10-01 00:45:00                    103003.900
# 2019-10-01 01:00:00                    102994.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2019-10-01 00:00:00                        4.400                6.60
# 2019-10-01 00:15:00                        4.325                6.40
# 2019-10-01 00:30:00                        4.250                6.20
# 2019-10-01 00:45:00                        4.175                6.00
# 2019-10-01 01:00:00                        4.100                5.80
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [38112 rows x 5 columns]

# %%
s = weather1.index >= '2020-11-01 10:00:00'
t = weather1.index < '2020-12-01 00:00:00'
weather_test1 = weather1[s&t]
weather_test1 = weather_test1[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test1
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train1 = weather_train1
X_train1 = (X_train1-X_train1.mean())/X_train1.std()

# %%
X_test1 = weather_test1
X_test1 = (X_test1-X_test1.mean())/X_test1.std()

# %%
Y_train1 = Solar1['Solar1']
Y_test1 = nov_data1['Solar1']

# %%
print('X_train:',X_train1.shape)
print('X_test:',X_test1.shape)
print('Y_train:',Y_train1.shape)
print('Y_test:',Y_test1.shape)
# Out:
# X_train: (38112, 5)
# X_test: (2840, 5)
# Y_train: (38112,)
# Y_test: (2840,)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=300,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train1, Y_train1)
predictions1 = regressor.predict(X_test1)

MSE = mean_squared_error(Y_test1, predictions1)
print("MSE:", MSE)

total = np.sum((Y_test1 - np.mean(Y_test1))**2)
residual = np.sum((Y_test1 - predictions1)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 3.928199939990407
# R^2: 0.7862550539817026

# %%
results1 = pd.DataFrame({'Actual': Y_test1, 'Predicted': predictions1})
results1
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00    7.95   6.184431
# 2020-11-01 10:15:00    8.51   6.378008
# 2020-11-01 10:30:00    9.07   6.789808
# 2020-11-01 10:45:00    9.38   7.208655
# 2020-11-01 11:00:00    9.68   7.327519
# ...                     ...        ...
# 2020-11-30 22:45:00    0.00   0.593698
# 2020-11-30 23:00:00    0.00   0.581581
# 2020-11-30 23:15:00    0.00   0.534186
# 2020-11-30 23:30:00    0.00   0.423546
# 2020-11-30 23:45:00    0.00   0.791278
#
# [2840 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results1['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results1['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Solar 2

# %%
Solar2 = df.drop(columns=['Solar0','Solar1','Solar3','Solar4','Solar5'])
Solar2
# Out:
#                       Date  Solar2
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00    4.73
# 151782 2020-11-01 09:00:00    5.64
# 151783 2020-11-01 09:15:00    5.99
# 151784 2020-11-01 09:30:00    6.35
# 151785 2020-11-01 09:45:00    7.30
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar2['Date'], Solar2['Solar2'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 2 power output')
plt.grid(True)
plt.show()

# %%
Solar2.set_index('Date', inplace=True)
s = Solar2.index > '2019-09-30 23:49:00'
t = Solar2.index < '2020-11-01 00:00:00'
Solar2 = Solar2[s&t]
Solar2
# Out:
#                      Solar2
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2019-09-30 23:49:00'
weather2 = weather[s]
weather2
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2019-10-01 00:00:00               6.600                        4.400
# 2019-10-01 00:15:00               6.400                        4.325
# 2019-10-01 00:30:00               6.200                        4.250
# 2019-10-01 00:45:00               6.000                        4.175
# 2019-10-01 01:00:00               5.800                        4.100
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00             2.100                    103031.800
# 2019-10-01 00:15:00             2.075                    103022.500
# 2019-10-01 00:30:00             2.050                    103013.200
# 2019-10-01 00:45:00             2.025                    103003.900
# 2019-10-01 01:00:00             2.000                    102994.600
# ...                               ...                           ...
# 2021-06-01 09:00:00             5.600                    102077.100
# 2021-06-01 09:15:00             5.550                    102085.225
# 2021-06-01 09:30:00             5.500                    102093.350
# 2021-06-01 09:45:00             5.450                    102101.475
# 2021-06-01 10:00:00             5.400                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2019-10-01 00:00:00                      0.900
# 2019-10-01 00:15:00                      0.900
# 2019-10-01 00:30:00                      0.900
# 2019-10-01 00:45:00                      0.900
# 2019-10-01 01:00:00                      0.900
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            0.000
# 2019-10-01 00:15:00                            0.000
# 2019-10-01 00:30:00                            0.000
# 2019-10-01 00:45:00                            0.000
# 2019-10-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2019-10-01 00:00:00                      0.1
# 2019-10-01 00:15:00                      0.1
# 2019-10-01 00:30:00                      0.1
# 2019-10-01 00:45:00                      0.1
# 2019-10-01 01:00:00                      0.1
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [58505 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar5','Solar0','Solar1','Solar3','Solar4'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data2 = nov_data[t]
nov_data2
# Out:
#                      Solar2
# Date
# 2020-11-01 10:00:00    8.26
# 2020-11-01 10:15:00    8.11
# 2020-11-01 10:30:00    7.95
# 2020-11-01 10:45:00    9.12
# 2020-11-01 11:00:00   10.29
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y - train (Solar 2)

# %%
Solar2
# Out:
#                      Solar2
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
nov_data2
# Out:
#                      Solar2
# Date
# 2020-11-01 10:00:00    8.26
# 2020-11-01 10:15:00    8.11
# 2020-11-01 10:30:00    7.95
# 2020-11-01 10:45:00    9.12
# 2020-11-01 11:00:00   10.29
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # X - train

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather2.index < '2020-11-01 00:00:00'
weather_train2 = weather2[t]
weather_train2 = weather_train2[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train2
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                              0.0
# 2019-10-01 00:15:00                              0.0
# 2019-10-01 00:30:00                              0.0
# 2019-10-01 00:45:00                              0.0
# 2019-10-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00                    103031.800
# 2019-10-01 00:15:00                    103022.500
# 2019-10-01 00:30:00                    103013.200
# 2019-10-01 00:45:00                    103003.900
# 2019-10-01 01:00:00                    102994.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2019-10-01 00:00:00                        4.400                6.60
# 2019-10-01 00:15:00                        4.325                6.40
# 2019-10-01 00:30:00                        4.250                6.20
# 2019-10-01 00:45:00                        4.175                6.00
# 2019-10-01 01:00:00                        4.100                5.80
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [38112 rows x 5 columns]

# %% [markdown]
# # X - test

# %%
s = weather2.index >= '2020-11-01 10:00:00'
t = weather2.index < '2020-12-01 00:00:00'
weather_test2 = weather2[s&t]
weather_test2 = weather_test2[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test2
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train2 = weather_train2
X_train2 = (X_train2-X_train2.mean())/X_train2.std()

# %%
X_test2 = weather_test2
X_test2 = (X_test2-X_test2.mean())/X_test2.std()

# %%
Y_train2 = Solar2['Solar2']
Y_test2 = nov_data2['Solar2']

# %%
print('X_train:',X_train2.shape)
print('X_test:',X_test2.shape)
print('Y_train:',Y_train2.shape)
print('Y_test:',Y_test2.shape)
# Out:
# X_train: (38112, 5)
# X_test: (2840, 5)
# Y_train: (38112,)
# Y_test: (2840,)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=300,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train2, Y_train2)
predictions2 = regressor.predict(X_test2)

MSE = mean_squared_error(Y_test2, predictions2)
print("MSE:", MSE)

total = np.sum((Y_test2 - np.mean(Y_test2))**2)
residual = np.sum((Y_test2 - predictions2)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 4.277817355596725
# R^2: 0.7661993633556441

# %%
results2 = pd.DataFrame({'Actual': Y_test2, 'Predicted': predictions2})
results2
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00    8.26   5.300642
# 2020-11-01 10:15:00    8.11   5.567809
# 2020-11-01 10:30:00    7.95   5.854962
# 2020-11-01 10:45:00    9.12   6.026973
# 2020-11-01 11:00:00   10.29   6.134245
# ...                     ...        ...
# 2020-11-30 22:45:00    0.00   0.344694
# 2020-11-30 23:00:00    0.00   0.337360
# 2020-11-30 23:15:00    0.00   0.332448
# 2020-11-30 23:30:00    0.00   0.302029
# 2020-11-30 23:45:00    0.00   0.255458
#
# [2840 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results2['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results2['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Solar 3

# %%
Solar3 = df.drop(columns=['Solar0','Solar1','Solar2','Solar4','Solar5'])
Solar3
# Out:
#                       Date  Solar3
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00    4.31
# 151782 2020-11-01 09:00:00    5.08
# 151783 2020-11-01 09:15:00    5.45
# 151784 2020-11-01 09:30:00    5.83
# 151785 2020-11-01 09:45:00    6.76
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar3['Date'], Solar3['Solar3'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 3 power output')
plt.grid(True)
plt.show()

# %%
Solar3.set_index('Date', inplace=True)
s = Solar3.index > '2019-09-30 23:49:00'
t = Solar3.index < '2020-11-01 00:00:00'
Solar3 = Solar3[s&t]
Solar3
# Out:
#                      Solar3
# Date
# 2019-10-01 00:00:00    5.39
# 2019-10-01 00:15:00    5.39
# 2019-10-01 00:30:00    5.39
# 2019-10-01 00:45:00    5.40
# 2019-10-01 01:00:00    5.40
# ...                     ...
# 2020-10-31 22:45:00    0.00
# 2020-10-31 23:00:00    0.00
# 2020-10-31 23:15:00    0.00
# 2020-10-31 23:30:00    0.00
# 2020-10-31 23:45:00    0.00
#
# [38112 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2019-09-30 23:49:00'
weather3 = weather[s]
weather3
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2019-10-01 00:00:00               6.600                        4.400
# 2019-10-01 00:15:00               6.400                        4.325
# 2019-10-01 00:30:00               6.200                        4.250
# 2019-10-01 00:45:00               6.000                        4.175
# 2019-10-01 01:00:00               5.800                        4.100
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00             2.100                    103031.800
# 2019-10-01 00:15:00             2.075                    103022.500
# 2019-10-01 00:30:00             2.050                    103013.200
# 2019-10-01 00:45:00             2.025                    103003.900
# 2019-10-01 01:00:00             2.000                    102994.600
# ...                               ...                           ...
# 2021-06-01 09:00:00             5.600                    102077.100
# 2021-06-01 09:15:00             5.550                    102085.225
# 2021-06-01 09:30:00             5.500                    102093.350
# 2021-06-01 09:45:00             5.450                    102101.475
# 2021-06-01 10:00:00             5.400                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2019-10-01 00:00:00                      0.900
# 2019-10-01 00:15:00                      0.900
# 2019-10-01 00:30:00                      0.900
# 2019-10-01 00:45:00                      0.900
# 2019-10-01 01:00:00                      0.900
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            0.000
# 2019-10-01 00:15:00                            0.000
# 2019-10-01 00:30:00                            0.000
# 2019-10-01 00:45:00                            0.000
# 2019-10-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2019-10-01 00:00:00                      0.1
# 2019-10-01 00:15:00                      0.1
# 2019-10-01 00:30:00                      0.1
# 2019-10-01 00:45:00                      0.1
# 2019-10-01 01:00:00                      0.1
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [58505 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar5','Solar0','Solar1','Solar2','Solar4'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data3 = nov_data[t]
nov_data3
# Out:
#                      Solar3
# Date
# 2020-11-01 10:00:00    7.69
# 2020-11-01 10:15:00    7.52
# 2020-11-01 10:30:00    7.35
# 2020-11-01 10:45:00    8.15
# 2020-11-01 11:00:00    8.96
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y - train (Solar 3)

# %%
Solar3
# Out:
#                      Solar3
# Date
# 2019-10-01 00:00:00    5.39
# 2019-10-01 00:15:00    5.39
# 2019-10-01 00:30:00    5.39
# 2019-10-01 00:45:00    5.40
# 2019-10-01 01:00:00    5.40
# ...                     ...
# 2020-10-31 22:45:00    0.00
# 2020-10-31 23:00:00    0.00
# 2020-10-31 23:15:00    0.00
# 2020-10-31 23:30:00    0.00
# 2020-10-31 23:45:00    0.00
#
# [38112 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
nov_data3
# Out:
#                      Solar3
# Date
# 2020-11-01 10:00:00    7.69
# 2020-11-01 10:15:00    7.52
# 2020-11-01 10:30:00    7.35
# 2020-11-01 10:45:00    8.15
# 2020-11-01 11:00:00    8.96
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # X - train

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather3.index < '2020-11-01 00:00:00'
weather_train3 = weather3[t]
weather_train3 = weather_train3[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train3
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                              0.0
# 2019-10-01 00:15:00                              0.0
# 2019-10-01 00:30:00                              0.0
# 2019-10-01 00:45:00                              0.0
# 2019-10-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00                    103031.800
# 2019-10-01 00:15:00                    103022.500
# 2019-10-01 00:30:00                    103013.200
# 2019-10-01 00:45:00                    103003.900
# 2019-10-01 01:00:00                    102994.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2019-10-01 00:00:00                        4.400                6.60
# 2019-10-01 00:15:00                        4.325                6.40
# 2019-10-01 00:30:00                        4.250                6.20
# 2019-10-01 00:45:00                        4.175                6.00
# 2019-10-01 01:00:00                        4.100                5.80
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [38112 rows x 5 columns]

# %% [markdown]
# # X - test

# %%
s = weather3.index >= '2020-11-01 10:00:00'
t = weather3.index < '2020-12-01 00:00:00'
weather_test3 = weather3[s&t]
weather_test3 = weather_test3[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test3
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train3 = weather_train3
X_train3 = (X_train3-X_train3.mean())/X_train3.std()

# %%
X_test3 = weather_test3
X_test3 = (X_test3-X_test3.mean())/X_test3.std()

# %%
Y_train3 = Solar3['Solar3']
Y_test3 = nov_data3['Solar3']

# %%
print('X_train:',X_train3.shape)
print('X_test:',X_test3.shape)
print('Y_train:',Y_train3.shape)
print('Y_test:',Y_test3.shape)
# Out:
# X_train: (38112, 5)
# X_test: (2840, 5)
# Y_train: (38112,)
# Y_test: (2840,)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=300,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train3, Y_train3)
predictions3 = regressor.predict(X_test3)

MSE = mean_squared_error(Y_test3, predictions3)
print("MSE:", MSE)

total = np.sum((Y_test3 - np.mean(Y_test3))**2)
residual = np.sum((Y_test3 - predictions3)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 4.962766951540577
# R^2: 0.6616373284350419

# %%
results3 = pd.DataFrame({'Actual': Y_test3, 'Predicted': predictions3})
results3
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00    7.69   4.629716
# 2020-11-01 10:15:00    7.52   4.812749
# 2020-11-01 10:30:00    7.35   4.939950
# 2020-11-01 10:45:00    8.15   4.982503
# 2020-11-01 11:00:00    8.96   5.084332
# ...                     ...        ...
# 2020-11-30 22:45:00    0.00   0.212610
# 2020-11-30 23:00:00    0.00   0.212610
# 2020-11-30 23:15:00    0.00   0.215739
# 2020-11-30 23:30:00    0.00   0.203459
# 2020-11-30 23:45:00    0.00   0.205898
#
# [2840 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results3['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results3['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Solar 4

# %%
Solar4 = df.drop(columns=['Solar0','Solar1','Solar2','Solar3','Solar5'])
Solar4
# Out:
#                       Date  Solar4
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00    2.84
# 151782 2020-11-01 09:00:00    3.40
# 151783 2020-11-01 09:15:00    3.62
# 151784 2020-11-01 09:30:00    3.85
# 151785 2020-11-01 09:45:00    4.49
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar4['Date'], Solar4['Solar4'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 4 power output')
plt.grid(True)
plt.show()

# %%
Solar4.set_index('Date', inplace=True)
s = Solar4.index > '2019-09-30 23:49:00'
t = Solar4.index < '2020-11-01 00:00:00'
Solar4 = Solar4[s&t]
Solar4
# Out:
#                      Solar4
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2019-09-30 23:49:00'
weather4 = weather[s]
weather4
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2019-10-01 00:00:00               6.600                        4.400
# 2019-10-01 00:15:00               6.400                        4.325
# 2019-10-01 00:30:00               6.200                        4.250
# 2019-10-01 00:45:00               6.000                        4.175
# 2019-10-01 01:00:00               5.800                        4.100
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00             2.100                    103031.800
# 2019-10-01 00:15:00             2.075                    103022.500
# 2019-10-01 00:30:00             2.050                    103013.200
# 2019-10-01 00:45:00             2.025                    103003.900
# 2019-10-01 01:00:00             2.000                    102994.600
# ...                               ...                           ...
# 2021-06-01 09:00:00             5.600                    102077.100
# 2021-06-01 09:15:00             5.550                    102085.225
# 2021-06-01 09:30:00             5.500                    102093.350
# 2021-06-01 09:45:00             5.450                    102101.475
# 2021-06-01 10:00:00             5.400                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2019-10-01 00:00:00                      0.900
# 2019-10-01 00:15:00                      0.900
# 2019-10-01 00:30:00                      0.900
# 2019-10-01 00:45:00                      0.900
# 2019-10-01 01:00:00                      0.900
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            0.000
# 2019-10-01 00:15:00                            0.000
# 2019-10-01 00:30:00                            0.000
# 2019-10-01 00:45:00                            0.000
# 2019-10-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2019-10-01 00:00:00                      0.1
# 2019-10-01 00:15:00                      0.1
# 2019-10-01 00:30:00                      0.1
# 2019-10-01 00:45:00                      0.1
# 2019-10-01 01:00:00                      0.1
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [58505 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar5','Solar0','Solar1','Solar2','Solar3'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data4 = nov_data[t]
nov_data4
# Out:
#                      Solar4
# Date
# 2020-11-01 10:00:00    5.13
# 2020-11-01 10:15:00    5.01
# 2020-11-01 10:30:00    4.89
# 2020-11-01 10:45:00    5.59
# 2020-11-01 11:00:00    6.29
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y - train (Solar 4)

# %%
Solar4
# Out:
#                      Solar4
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
nov_data4
# Out:
#                      Solar4
# Date
# 2020-11-01 10:00:00    5.13
# 2020-11-01 10:15:00    5.01
# 2020-11-01 10:30:00    4.89
# 2020-11-01 10:45:00    5.59
# 2020-11-01 11:00:00    6.29
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # X-train

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather4.index < '2020-11-01 00:00:00'
weather_train4 = weather4[t]
weather_train4 = weather_train4[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train4
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                              0.0
# 2019-10-01 00:15:00                              0.0
# 2019-10-01 00:30:00                              0.0
# 2019-10-01 00:45:00                              0.0
# 2019-10-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00                    103031.800
# 2019-10-01 00:15:00                    103022.500
# 2019-10-01 00:30:00                    103013.200
# 2019-10-01 00:45:00                    103003.900
# 2019-10-01 01:00:00                    102994.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2019-10-01 00:00:00                        4.400                6.60
# 2019-10-01 00:15:00                        4.325                6.40
# 2019-10-01 00:30:00                        4.250                6.20
# 2019-10-01 00:45:00                        4.175                6.00
# 2019-10-01 01:00:00                        4.100                5.80
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [38112 rows x 5 columns]

# %% [markdown]
# # X - test

# %%
s = weather4.index >= '2020-11-01 10:00:00'
t = weather4.index < '2020-12-01 00:00:00'
weather_test4 = weather4[s&t]
weather_test4 = weather_test4[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test4
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train4 = weather_train4
X_train4 = (X_train4-X_train4.mean())/X_train4.std()

# %%
X_test4 = weather_test4
X_test4 = (X_test4-X_test4.mean())/X_test4.std()

# %%
Y_train4 = Solar4['Solar4']
Y_test4 = nov_data4['Solar4']

# %%
print('X_train:',X_train4.shape)
print('X_test:',X_test4.shape)
print('Y_train:',Y_train4.shape)
print('Y_test:',Y_test4.shape)
# Out:
# X_train: (38112, 5)
# X_test: (2840, 5)
# Y_train: (38112,)
# Y_test: (2840,)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=300,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train4, Y_train4)
predictions4 = regressor.predict(X_test4)

MSE = mean_squared_error(Y_test4, predictions4)
print("MSE:", MSE)

total = np.sum((Y_test4 - np.mean(Y_test4))**2)
residual = np.sum((Y_test4 - predictions4)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 1.4349378959953845
# R^2: 0.7771200838071665

# %%
results4 = pd.DataFrame({'Actual': Y_test4, 'Predicted': predictions4})
results4
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00    5.13   3.273001
# 2020-11-01 10:15:00    5.01   3.561500
# 2020-11-01 10:30:00    4.89   3.767701
# 2020-11-01 10:45:00    5.59   3.959977
# 2020-11-01 11:00:00    6.29   4.128044
# ...                     ...        ...
# 2020-11-30 22:45:00    0.00   0.197213
# 2020-11-30 23:00:00    0.00   0.197213
# 2020-11-30 23:15:00    0.00   0.197213
# 2020-11-30 23:30:00    0.00   0.197213
# 2020-11-30 23:45:00    0.00   0.193982
#
# [2840 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results4['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results4['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Solar 5

# %%
Solar5 = df.drop(columns=['Solar0','Solar1','Solar2','Solar3','Solar4'])
Solar5
# Out:
#                       Date  Solar5
# 0      2016-07-04 07:30:00     NaN
# 1      2016-07-04 07:45:00     NaN
# 2      2016-07-04 08:00:00     NaN
# 3      2016-07-04 08:15:00     NaN
# 4      2016-07-04 08:30:00     NaN
# ...                    ...     ...
# 151781 2020-11-01 08:45:00   13.47
# 151782 2020-11-01 09:00:00   15.93
# 151783 2020-11-01 09:15:00   17.11
# 151784 2020-11-01 09:30:00   18.29
# 151785 2020-11-01 09:45:00   20.64
#
# [151786 rows x 2 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(Solar5['Date'], Solar5['Solar5'])
plt.xlabel('Months')
plt.ylabel('Power output')
plt.title('Solar 5 power output')
plt.grid(True)
plt.show()

# %%
Solar5.set_index('Date', inplace=True)
s = Solar5.index > '2019-09-30 23:49:00'
t = Solar5.index < '2020-11-01 00:00:00'
Solar5 = Solar5[s&t]
Solar5
# Out:
#                      Solar5
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %%
weather = pd.read_csv("monash_weather.csv")
weather = weather.set_index(pd.DatetimeIndex(weather['datetime (UTC)'])).drop(weather.columns[0], axis=1)
weather = weather.resample("15T").mean().round(1) #Resampling into 15-minute intervals
weather = weather.interpolate(method='linear') #Input NaN
weather.index.names = ['timestamp']
s = weather.index > '2019-09-30 23:49:00'
weather5 = weather[s]
weather5
# Out:
#                      temperature (degC)  dewpoint_temperature (degC)  \
# timestamp
# 2019-10-01 00:00:00               6.600                        4.400
# 2019-10-01 00:15:00               6.400                        4.325
# 2019-10-01 00:30:00               6.200                        4.250
# 2019-10-01 00:45:00               6.000                        4.175
# 2019-10-01 01:00:00               5.800                        4.100
# ...                                 ...                          ...
# 2021-06-01 09:00:00               9.800                        3.900
# 2021-06-01 09:15:00              10.025                        3.975
# 2021-06-01 09:30:00              10.250                        4.050
# 2021-06-01 09:45:00              10.475                        4.125
# 2021-06-01 10:00:00              10.700                        4.200
#
#                      wind_speed (m/s)  mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00             2.100                    103031.800
# 2019-10-01 00:15:00             2.075                    103022.500
# 2019-10-01 00:30:00             2.050                    103013.200
# 2019-10-01 00:45:00             2.025                    103003.900
# 2019-10-01 01:00:00             2.000                    102994.600
# ...                               ...                           ...
# 2021-06-01 09:00:00             5.600                    102077.100
# 2021-06-01 09:15:00             5.550                    102085.225
# 2021-06-01 09:30:00             5.500                    102093.350
# 2021-06-01 09:45:00             5.450                    102101.475
# 2021-06-01 10:00:00             5.400                    102109.600
#
#                      relative_humidity ((0-1))  \
# timestamp
# 2019-10-01 00:00:00                      0.900
# 2019-10-01 00:15:00                      0.900
# 2019-10-01 00:30:00                      0.900
# 2019-10-01 00:45:00                      0.900
# 2019-10-01 01:00:00                      0.900
# ...                                        ...
# 2021-06-01 09:00:00                      0.700
# 2021-06-01 09:15:00                      0.675
# 2021-06-01 09:30:00                      0.650
# 2021-06-01 09:45:00                      0.625
# 2021-06-01 10:00:00                      0.600
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            0.000
# 2019-10-01 00:15:00                            0.000
# 2019-10-01 00:30:00                            0.000
# 2019-10-01 00:45:00                            0.000
# 2019-10-01 01:00:00                            0.000
# ...                                              ...
# 2021-06-01 09:00:00                           80.500
# 2021-06-01 09:15:00                           97.825
# 2021-06-01 09:30:00                          115.150
# 2021-06-01 09:45:00                          132.475
# 2021-06-01 10:00:00                          149.800
#
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2021-06-01 09:00:00                            296.200
# 2021-06-01 09:15:00                            298.500
# 2021-06-01 09:30:00                            300.800
# 2021-06-01 09:45:00                            303.100
# 2021-06-01 10:00:00                            305.400
#
#                      total_cloud_cover (0-1)
# timestamp
# 2019-10-01 00:00:00                      0.1
# 2019-10-01 00:15:00                      0.1
# 2019-10-01 00:30:00                      0.1
# 2019-10-01 00:45:00                      0.1
# 2019-10-01 01:00:00                      0.1
# ...                                      ...
# 2021-06-01 09:00:00                      1.0
# 2021-06-01 09:15:00                      1.0
# 2021-06-01 09:30:00                      1.0
# 2021-06-01 09:45:00                      1.0
# 2021-06-01 10:00:00                      1.0
#
# [58505 rows x 8 columns]

# %%
nov_data = pd.read_csv('NOV_test_data.csv')
nov_data = nov_data.iloc[:, 1:]
nov_data['Date'] = pd.to_datetime(nov_data['Date'])
nov_data = nov_data.drop(columns=['Building0','Building1','Building3','Building4','Building5','Building6','Solar4','Solar0','Solar1','Solar2','Solar3'])
nov_data.set_index('Date', inplace=True)
t = nov_data.index < '2020-12-01 00:00:00'
nov_data5 = nov_data[t]
nov_data5
# Out:
#                      Solar5
# Date
# 2020-11-01 10:00:00   23.01
# 2020-11-01 10:15:00   23.73
# 2020-11-01 10:30:00   24.45
# 2020-11-01 10:45:00   28.05
# 2020-11-01 11:00:00   31.63
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %% [markdown]
# # Y - train (Solar 5)

# %%
Solar5
# Out:
#                      Solar5
# Date
# 2019-10-01 00:00:00     0.0
# 2019-10-01 00:15:00     0.0
# 2019-10-01 00:30:00     0.0
# 2019-10-01 00:45:00     0.0
# 2019-10-01 01:00:00     0.0
# ...                     ...
# 2020-10-31 22:45:00     0.0
# 2020-10-31 23:00:00     0.0
# 2020-10-31 23:15:00     0.0
# 2020-10-31 23:30:00     0.0
# 2020-10-31 23:45:00     0.0
#
# [38112 rows x 1 columns]

# %% [markdown]
# # Y - test

# %%
nov_data5
# Out:
#                      Solar5
# Date
# 2020-11-01 10:00:00   23.01
# 2020-11-01 10:15:00   23.73
# 2020-11-01 10:30:00   24.45
# 2020-11-01 10:45:00   28.05
# 2020-11-01 11:00:00   31.63
# ...                     ...
# 2020-11-30 22:45:00    0.00
# 2020-11-30 23:00:00    0.00
# 2020-11-30 23:15:00    0.00
# 2020-11-30 23:30:00    0.00
# 2020-11-30 23:45:00    0.00
#
# [2840 rows x 1 columns]

# %%
'''
* Surface  Thermal Radiation
* Surface Solar Radiation
* MSLP
* Dew Point Temperature
* Air Temperature
'''

t = weather5.index < '2020-11-01 00:00:00'
weather_train5 = weather5[t]
weather_train5 = weather_train5[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_train5
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                            260.300
# 2019-10-01 00:15:00                            260.025
# 2019-10-01 00:30:00                            259.750
# 2019-10-01 00:45:00                            259.475
# 2019-10-01 01:00:00                            259.200
# ...                                                ...
# 2020-10-31 22:45:00                            336.375
# 2020-10-31 23:00:00                            332.000
# 2020-10-31 23:15:00                            330.850
# 2020-10-31 23:30:00                            329.700
# 2020-10-31 23:45:00                            328.550
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2019-10-01 00:00:00                              0.0
# 2019-10-01 00:15:00                              0.0
# 2019-10-01 00:30:00                              0.0
# 2019-10-01 00:45:00                              0.0
# 2019-10-01 01:00:00                              0.0
# ...                                              ...
# 2020-10-31 22:45:00                              0.0
# 2020-10-31 23:00:00                              0.0
# 2020-10-31 23:15:00                              0.0
# 2020-10-31 23:30:00                              0.0
# 2020-10-31 23:45:00                              0.0
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2019-10-01 00:00:00                    103031.800
# 2019-10-01 00:15:00                    103022.500
# 2019-10-01 00:30:00                    103013.200
# 2019-10-01 00:45:00                    103003.900
# 2019-10-01 01:00:00                    102994.600
# ...                                           ...
# 2020-10-31 22:45:00                    101948.875
# 2020-10-31 23:00:00                    101948.000
# 2020-10-31 23:15:00                    101959.000
# 2020-10-31 23:30:00                    101970.000
# 2020-10-31 23:45:00                    101981.000
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2019-10-01 00:00:00                        4.400                6.60
# 2019-10-01 00:15:00                        4.325                6.40
# 2019-10-01 00:30:00                        4.250                6.20
# 2019-10-01 00:45:00                        4.175                6.00
# 2019-10-01 01:00:00                        4.100                5.80
# ...                                          ...                 ...
# 2020-10-31 22:45:00                        9.375               12.05
# 2020-10-31 23:00:00                        9.300               12.00
# 2020-10-31 23:15:00                        9.250               11.95
# 2020-10-31 23:30:00                        9.200               11.90
# 2020-10-31 23:45:00                        9.150               11.85
#
# [38112 rows x 5 columns]

# %%
s = weather5.index >= '2020-11-01 10:00:00'
t = weather5.index < '2020-12-01 00:00:00'
weather_test5 = weather5[s&t]
weather_test5 = weather_test5[['surface_thermal_radiation (W/m^2)','surface_solar_radiation (W/m^2)','mean_sea_level_pressure (Pa)','dewpoint_temperature (degC)','temperature (degC)']]
weather_test5
# Out:
#                      surface_thermal_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                            355.400
# 2020-11-01 10:15:00                            353.825
# 2020-11-01 10:30:00                            352.250
# 2020-11-01 10:45:00                            350.675
# 2020-11-01 11:00:00                            349.100
# ...                                                ...
# 2020-11-30 22:45:00                            357.950
# 2020-11-30 23:00:00                            357.300
# 2020-11-30 23:15:00                            356.000
# 2020-11-30 23:30:00                            354.700
# 2020-11-30 23:45:00                            353.400
#
#                      surface_solar_radiation (W/m^2)  \
# timestamp
# 2020-11-01 10:00:00                           497.60
# 2020-11-01 10:15:00                           544.05
# 2020-11-01 10:30:00                           590.50
# 2020-11-01 10:45:00                           636.95
# 2020-11-01 11:00:00                           683.40
# ...                                              ...
# 2020-11-30 22:45:00                             0.00
# 2020-11-30 23:00:00                             0.00
# 2020-11-30 23:15:00                             0.00
# 2020-11-30 23:30:00                             0.00
# 2020-11-30 23:45:00                             0.00
#
#                      mean_sea_level_pressure (Pa)  \
# timestamp
# 2020-11-01 10:00:00                    102398.800
# 2020-11-01 10:15:00                    102398.025
# 2020-11-01 10:30:00                    102397.250
# 2020-11-01 10:45:00                    102396.475
# 2020-11-01 11:00:00                    102395.700
# ...                                           ...
# 2020-11-30 22:45:00                    100671.375
# 2020-11-30 23:00:00                    100667.600
# 2020-11-30 23:15:00                    100633.300
# 2020-11-30 23:30:00                    100599.000
# 2020-11-30 23:45:00                    100564.700
#
#                      dewpoint_temperature (degC)  temperature (degC)
# timestamp
# 2020-11-01 10:00:00                        9.300              14.400
# 2020-11-01 10:15:00                        9.400              14.750
# 2020-11-01 10:30:00                        9.500              15.100
# 2020-11-01 10:45:00                        9.600              15.450
# 2020-11-01 11:00:00                        9.700              15.800
# ...                                          ...                 ...
# 2020-11-30 22:45:00                       15.575              18.875
# 2020-11-30 23:00:00                       15.600              18.700
# 2020-11-30 23:15:00                       15.550              18.625
# 2020-11-30 23:30:00                       15.500              18.550
# 2020-11-30 23:45:00                       15.450              18.475
#
# [2840 rows x 5 columns]

# %%
X_train5 = weather_train5
X_train5 = (X_train5-X_train5.mean())/X_train5.std()

# %%
X_test5 = weather_test5
X_test5 = (X_test5-X_test5.mean())/X_test5.std()

# %%
Y_train5 = Solar5['Solar5']
Y_test5 = nov_data5['Solar5']

# %%
print('X_train:',X_train5.shape)
print('X_test:',X_test5.shape)
print('Y_train:',Y_train5.shape)
print('Y_test:',Y_test5.shape)
# Out:
# X_train: (38112, 5)
# X_test: (2840, 5)
# Y_train: (38112,)
# Y_test: (2840,)

# %%
regressor = xgb.XGBRegressor(
    objective='reg:squarederror',  # Specify the objective for regression
    n_estimators=300,  # Number of boosting rounds
    learning_rate=0.03,  # Learning rate (step size)
    max_depth=3,  # Maximum depth of each tree
    random_state=42  # Random seed for reproducibility
)

regressor.fit(X_train5, Y_train5)
predictions5 = regressor.predict(X_test5)

MSE = mean_squared_error(Y_test5, predictions5)
print("MSE:", MSE)

total = np.sum((Y_test5 - np.mean(Y_test5))**2)
residual = np.sum((Y_test5 - predictions5)**2)
r_2 = 1-(residual/total)
print("R^2:", r_2)
# Out:
# MSE: 38.740324158006445
# R^2: 0.7678444246074565

# %%
results5 = pd.DataFrame({'Actual': Y_test5, 'Predicted': predictions5})
results5
# Out:
#                      Actual  Predicted
# Date
# 2020-11-01 10:00:00   23.01  17.261061
# 2020-11-01 10:15:00   23.73  18.510828
# 2020-11-01 10:30:00   24.45  19.113796
# 2020-11-01 10:45:00   28.05  20.777449
# 2020-11-01 11:00:00   31.63  21.446501
# ...                     ...        ...
# 2020-11-30 22:45:00    0.00   0.185276
# 2020-11-30 23:00:00    0.00   0.185276
# 2020-11-30 23:15:00    0.00   0.185908
# 2020-11-30 23:30:00    0.00   0.185908
# 2020-11-30 23:45:00    0.00   0.185908
#
# [2840 rows x 2 columns]

# %%
plt.figure(figsize=(8, 8))
plt.plot(results.index, results5['Predicted'], label='Predicted Value', marker='o')
plt.plot(results.index, results5['Actual'], label='Actual Value', marker='x')
plt.xlabel('Timestamp')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values Over Time')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
